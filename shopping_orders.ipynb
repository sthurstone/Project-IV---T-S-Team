# %%
import pandas as pd
import numpy as np

# %%
orders_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\Grocery_Products_Purchase.csv')
orders_df.head()
# Out:
#           Product 1            Product 2       Product 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                   Product 4 Product 5 Product 6 Product 7 Product 8 Product 9  \
# 0               ready soups       NaN       NaN       NaN       NaN       NaN
# 1                       NaN       NaN       NaN       NaN       NaN       NaN
# 2                       NaN       NaN       NaN       NaN       NaN       NaN
# 3              meat spreads       NaN       NaN       NaN       NaN       NaN
# 4  long life bakery product       NaN       NaN       NaN       NaN       NaN
#
#   Product 10  ... Product 23 Product 24 Product 25 Product 26 Product 27  \
# 0        NaN  ...        NaN        NaN        NaN        NaN        NaN
# ...

# %%
orders_df
# Out:
#                 Product 1            Product 2         Product 3  \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                  NaN               NaN
# 3               pip fruit               yogurt      cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                  NaN               NaN
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                      Product 4      Product 5       Product 6  \
# 0                  ready soups            NaN             NaN
# ...

# %%
orders_df = orders_df.drop(['Product 23', 'Product 24', 'Product 25', 'Product 26', 'Product 27',
                           'Product 28', 'Product 29', 'Product 30', 'Product 31', 'Product 32'], axis=1)

# %%
orders_df
# Out:
#                 Product 1            Product 2         Product 3  \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                  NaN               NaN
# 3               pip fruit               yogurt      cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                  NaN               NaN
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                      Product 4      Product 5       Product 6  \
# 0                  ready soups            NaN             NaN
# ...

# %%
orders2_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\GroceryStoreDataSet.csv')
orders2_df.head()
# Out:
#               MILK,BREAD,BISCUIT
# 0  BREAD,MILK,BISCUIT,CORNFLAKES
# 1            BREAD,TEA,BOURNVITA
# 2           JAM,MAGGI,BREAD,MILK
# 3              MAGGI,TEA,BISCUIT
# 4            BREAD,TEA,BOURNVITA

# %%
store_demand_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\Costs2.csv')
store_demand_df.head()
# Out:
#    Price                 Product  Unit Cost  Demanda  Order Cost
# 0  12.25  air fresheners candles      10.04       39          28
# 1  22.95             asian foods      20.65      245           9
# 2  28.92        baby accessories      22.27       13          21
# 3  24.99     baby bath body care      20.99       14           5
# 4  19.98       baby food formula      15.58      505           4

# %%
store_demand_df
# Out:
#      Price                        Product  Unit Cost  Demanda  Order Cost
# 0    12.25         air fresheners candles      10.04       39          28
# 1    22.95                    asian foods      20.65      245           9
# 2    28.92               baby accessories      22.27       13          21
# 3    24.99            baby bath body care      20.99       14           5
# 4    19.98              baby food formula      15.58      505           4
# ..     ...                            ...        ...      ...         ...
# 129  10.99              trash bags liners       9.01       66           4
# 130  17.89           vitamins supplements      15.21       74          10
# 131   4.19  water seltzer sparkling water       3.48     1418           4
# 132  13.99                    white wines      10.91       23          13
# 133   3.89                         yogurt       3.46     2172           4
#
# [134 rows x 5 columns]

# %%
market_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\Market_Basket_Optimisation.csv')
market_df.head()
# Out:
#           item_1     item_2      item_3
# 0         shrimp    almonds     avocado
# 1        burgers  meatballs        eggs
# 2        chutney        NaN         NaN
# 3         turkey    avocado         NaN
# 4  mineral water       milk  energy bar

# %%
market2_df = market_df.dropna()
market2_df.head()
# Out:
#               item_1       item_2      item_3
# 0             shrimp      almonds     avocado
# 1            burgers    meatballs        eggs
# 4      mineral water         milk  energy bar
# 7               soup  light cream     shallot
# 8  frozen vegetables    spaghetti   green tea

# %%
market2_df
# Out:
#                  item_1             item_2        item_3
# 0                shrimp            almonds       avocado
# 1               burgers          meatballs          eggs
# 4         mineral water               milk    energy bar
# 7                  soup        light cream       shallot
# 8     frozen vegetables          spaghetti     green tea
# ...                 ...                ...           ...
# 7493            burgers             salmon      pancakes
# 7494             turkey            burgers  dessert wine
# 7496             butter         light mayo   fresh bread
# 7497            burgers  frozen vegetables          eggs
# 7500               eggs    frozen smoothie   yogurt cake
#
# [4389 rows x 3 columns]

# %%
orders2_df = orders_df.dropna()
orders2_df.head()
# Out:
#          Product 1          Product 2       Product 3        Product 4  \
# 185    frankfurter                ham  tropical fruit        pip fruit
# 996        chicken     tropical fruit       pip fruit  root vegetables
# 1091       sausage  finished products  tropical fruit        pip fruit
# 1216   frankfurter            sausage      liver loaf              ham
# 2169  citrus fruit     tropical fruit       pip fruit           grapes
#
#              Product 5         Product 6      Product 7       Product 8  \
# 185    root vegetables  other vegetables     whole milk          butter
# 996   other vegetables        whole milk         butter          yogurt
# 1091  other vegetables            butter           curd         dessert
# 1216           chicken              beef   citrus fruit  tropical fruit
# 2169            onions  other vegetables  sliced cheese    cream cheese
#
#                Product 9        Product 10  ...         Product 13  \
# ...

# %%
orders2_df
# Out:
#          Product 1          Product 2        Product 3         Product 4  \
# 185    frankfurter                ham   tropical fruit         pip fruit
# 996        chicken     tropical fruit        pip fruit   root vegetables
# 1091       sausage  finished products   tropical fruit         pip fruit
# 1216   frankfurter            sausage       liver loaf               ham
# 2169  citrus fruit     tropical fruit        pip fruit            grapes
# 2469    liver loaf                ham        pip fruit   root vegetables
# 2938          meat             turkey   tropical fruit   root vegetables
# 2947   frankfurter               pork             beef    hamburger meat
# 2973          beef     hamburger meat   tropical fruit   root vegetables
# 4190   frankfurter            chicken             pork              beef
# 4430   frankfurter            sausage       liver loaf              beef
# 5610       sausage          pip fruit  root vegetables            onions
# ...

# %%
shopping_cart_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\dataset_group.csv')
shopping_cart_df.head()
# Out:
#        date  cart_id        product
# 0  1/1/2000        1         yogurt
# 1  1/1/2000        1           pork
# 2  1/1/2000        1  sandwich bags
# 3  1/1/2000        1     lunch meat
# 4  1/1/2000        1   all- purpose

# %%
shopping_cart_df
# Out:
#             date  cart_id            product
# 0       1/1/2000        1             yogurt
# 1       1/1/2000        1               pork
# 2       1/1/2000        1      sandwich bags
# 3       1/1/2000        1         lunch meat
# 4       1/1/2000        1       all- purpose
# ...          ...      ...                ...
# 22338  2/26/2002     1139               soda
# 22339  2/26/2002     1139  laundry detergent
# 22340  2/26/2002     1139         vegetables
# 22341  2/26/2002     1139            shampoo
# 22342  2/26/2002     1139         vegetables
#
# [22343 rows x 3 columns]

# %%
grouped_df = shopping_cart_df.groupby('cart_id')
grouped_df.first()
# Out:
#               date          product
# cart_id
# 1         1/1/2000           yogurt
# 2         1/1/2000     toilet paper
# 3         1/2/2000             soda
# 4         1/2/2000          cereals
# 5         1/2/2000  sandwich loaves
# ...            ...              ...
# 1135     2/22/2002            sugar
# 1136     2/23/2002       coffee/tea
# 1137     2/24/2002             beef
# 1138     2/25/2002    sandwich bags
# 1139     2/26/2002             soda
#
# [1139 rows x 2 columns]

# %%
dataset_df = pd.read_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\dataset.csv')
dataset_df.head()
# Out:
#    product1        product2     product3       product4       product5  \
# 0      pork   sandwich bags   lunch meat   all- purpose          flour
# 1   shampoo       hand soap      waffles     vegetables        cheeses
# 2      pork            soap    ice cream   toilet paper   dinner rolls
# 3     juice      lunch meat         soda   toilet paper   all- purpose
# 4     pasta       tortillas        mixes      hand soap   toilet paper
#
#       product6          product7        product8            product9  \
# 0         soda            butter      vegetables                beef
# 1        mixes              milk   sandwich bags   laundry detergent
# 2    hand soap   spaghetti sauce            milk             ketchup
# 3                            NaN             NaN                 NaN
# 4   vegetables        vegetables    paper towels          vegetables
#
#                        product10      product11          product12  \
# ...

# %%
dataset2_df = dataset_df.dropna()
dataset2_df
# Out:
#            product1        product2          product3       product4  \
# 0              pork   sandwich bags        lunch meat   all- purpose
# 1           shampoo       hand soap           waffles     vegetables
# 2              pork            soap         ice cream   toilet paper
# 4             pasta       tortillas             mixes      hand soap
# 5      toilet paper            eggs      toilet paper     vegetables
# ...             ...             ...               ...            ...
# 1492         butter       hand soap            bagels           soap
# 1494           beef   sandwich bags         hand soap   paper towels
# 1495   dinner rolls      lunch meat   spaghetti sauce          pasta
# 1496     lunch meat            eggs           poultry     vegetables
# 1497        ketchup            milk           poultry        cheeses
#
#                 product5                       product6          product7  \
# ...

# %%
shopping_cart_df.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\shopping_cart_cleaned.csv')

# %%
dataset2_df.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\dataset_cleaned.csv')

# %%
orders2_df.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\orders_cleaned.csv')

# %%
market2_df.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\market_cleaned.csv')

# %%
dataset2_count = dataset2_df.stack().value_counts()
dataset2_count
# Out:
#  vegetables                      1109
#  poultry                          438
#  soda                             421
#  cheeses                          408
#  soap                             407
#  mixes                            407
#  waffles                          402
#  juice                            397
#  ice cream                        395
#  spaghetti sauce                  393
#  dishwashing liquid/detergent     393
#  toilet paper                     393
#  paper towels                     391
#  butter                           389
#  bagels                           388
#  flour                            383
#  lunch meat                       381
#  aluminum foil                    378
#  sandwich bags                    376
#  ketchup                          375
#  eggs                             374
#  sugar                            373
#  cereals                          373
#  dinner rolls                     370
#  milk                             370
# ...

# %%
shopping_cart_count = shopping_cart_df['product'].value_counts()
shopping_cart_count
# Out:
# vegetables                      1702
# poultry                          640
# soda                             597
# cereals                          591
# ice cream                        579
# cheeses                          578
# waffles                          575
# soap                             574
# bagels                           573
# lunch meat                       573
# eggs                             570
# juice                            570
# toilet paper                     569
# dinner rolls                     567
# aluminum foil                    566
# coffee/tea                       565
# shampoo                          562
# beef                             561
# paper towels                     556
# flour                            555
# milk                             555
# butter                           555
# mixes                            554
# all- purpose                     551
# dishwashing liquid/detergent     551
# ...

# %%
orders2count = orders2_df.stack().value_counts()
orders2count
# Out:
# other vegetables        14
# tropical fruit          14
# yogurt                  13
# whole milk              13
# root vegetables         12
#                         ..
# potted plants            1
# cream                    1
# specialty vegetables     1
# specialty chocolate      1
# meat                     1
# Length: 108, dtype: int64

# %%
market2count = market2_df.stack().value_counts()
print(market2count)
# Out:
# mineral water        1165
# spaghetti             891
# frozen vegetables     627
# ground beef           597
# chocolate             582
#                      ...
# sandwich                3
# cream                   2
# zucchini                2
# cauliflower             1
# water spray             1
# Length: 117, dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = market2count.plot(kind='line')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_ylabel("Number Sold")
ax.set_title("Number of Product Sold")
# Out:
# Text(0.5, 1.0, 'Number of Product Sold')

# %%
dataset2_count.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\dataset_count.csv')
shopping_cart_count.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\shopping_cart_count.csv')
orders2count.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\orders2count.csv')
market2count.to_csv(r'C:\Users\tsatr\Documents\BootCamp\Project-IV---T-S-Team\Resources\market2count.csv')
