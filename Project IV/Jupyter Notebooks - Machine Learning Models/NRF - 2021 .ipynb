# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
NRF=pd.read_csv("NRF.csv")
NRF.head(5)
# Out:
#    Rank           Company  2020 worldwide retail sales (billions)
# 0     1           Walmart                                  543.17
# 1     2        Amazon.com                                  263.16
# 2     3    The Kroger Co.                                  131.57
# 3     4    The Home Depot                                  129.89
# 4     5  Costco Wholesale                                  162.48

# %%
NRF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Rank                                    100 non-null    int64
#  1   Company                                 100 non-null    object
#  2   2020 worldwide retail sales (billions)  100 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
NRF2=NRF.rename(columns={"2020 worldwide retail sales (billions)": "2020 Sales (Billions)"})
NRF2
# Out:
#     Rank           Company  2020 Sales (Billions)
# 0      1           Walmart                 543.17
# 1      2        Amazon.com                 263.16
# 2      3    The Kroger Co.                 131.57
# 3      4    The Home Depot                 129.89
# 4      5  Costco Wholesale                 162.48
# ..   ...               ...                    ...
# 95    96    Grocery Outlet                   3.13
# 96    97              Belk                   3.13
# 97    98         Lululemon                   3.79
# 98    99    Sears Holdings                   3.26
# 99   100              AMPM                   4.35
#
# [100 rows x 3 columns]

# %%
NRF3=NRF2.nlargest(n=10, columns=['2020 Sales (Billions)'])
NRF3
# Out:
#     Rank                   Company  2020 Sales (Billions)
# 0      1                   Walmart                 543.17
# 1      2                Amazon.com                 263.16
# 4      5          Costco Wholesale                 162.48
# 2      3            The Kroger Co.                 131.57
# 3      4            The Home Depot                 129.89
# 14    15                      Aldi                 120.09
# 5      6  Walgreens Boots Alliance                 117.74
# 6      7                    Target                  92.40
# 7      8    CVS Health Corporation                  89.94
# 22    23                  7-Eleven                  87.94

# %%
NRF3.plot(x ='Company', y='2020 Sales (Billions)', kind = 'bar', color='maroon', figsize=(10, 10))
plt.ylabel("2020 Sales (Billions)")
plt.xlabel("Retail Giant")
plt.title("National Retail Federation - Top Ten Retail Giants, 2020")
plt.savefig('NRF.png')
